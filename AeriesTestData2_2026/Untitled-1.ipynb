# %%
# Loaded variable 'df' from URI: /Users/flucido/Desktop/AeRIES test data/grades_gpa/grades_2020_2021.csv
import pandas as pd
df = pd.read_csv(r'/Users/flucido/Desktop/AeRIES test data/grades_gpa/grades_2020_2021.csv')
